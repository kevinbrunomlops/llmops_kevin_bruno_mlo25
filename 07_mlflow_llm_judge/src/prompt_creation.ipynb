# %% [markdown]
# # Prompt creation and versioning

# %%
from mlflow.genai import register_prompt

register_prompt
# Out:
# <function mlflow.genai.prompts.register_prompt(name: str, template: str | list[dict[str, typing.Any]], commit_message: str | None = None, tags: dict[str, str] | None = None, response_format: type[pydantic.main.BaseModel] | dict[str, typing.Any] | None = None, model_config: mlflow.entities.model_registry.prompt_version.PromptModelConfig | dict[str, typing.Any] | None = None) -> mlflow.entities.model_registry.prompt_version.PromptVersion>
